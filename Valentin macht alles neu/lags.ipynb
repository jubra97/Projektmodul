# %%
import torch
from utilities import lag_matrix

# %%
r = torch.rand(30)
y = lag_matrix(r, 6)

# %%
y
# Out:
# tensor([[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.2235],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.2235, 0.6179],
#         [0.0000, 0.0000, 0.0000, 0.2235, 0.6179, 0.7089],
#         [0.0000, 0.0000, 0.2235, 0.6179, 0.7089, 0.8794],
#         [0.0000, 0.2235, 0.6179, 0.7089, 0.8794, 0.7221],
#         [0.2235, 0.6179, 0.7089, 0.8794, 0.7221, 0.0696],
#         [0.6179, 0.7089, 0.8794, 0.7221, 0.0696, 0.4315],
#         [0.7089, 0.8794, 0.7221, 0.0696, 0.4315, 0.0189],
#         [0.8794, 0.7221, 0.0696, 0.4315, 0.0189, 0.3455],
#         [0.7221, 0.0696, 0.4315, 0.0189, 0.3455, 0.0893],
#         [0.0696, 0.4315, 0.0189, 0.3455, 0.0893, 0.4043],
#         [0.4315, 0.0189, 0.3455, 0.0893, 0.4043, 0.1535],
#         [0.0189, 0.3455, 0.0893, 0.4043, 0.1535, 0.4514],
#         [0.3455, 0.0893, 0.4043, 0.1535, 0.4514, 0.8199],
#         [0.0893, 0.4043, 0.1535, 0.4514, 0.8199, 0.8000],
#         [0.4043, 0.1535, 0.4514, 0.8199, 0.8000, 0.8259],
# ...
